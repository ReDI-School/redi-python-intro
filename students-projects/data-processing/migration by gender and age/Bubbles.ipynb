# %% [markdown]
# # Female, male, and minors, migration ration per country for 2017

# %%
import csv

def print_data_from_csv(filename):
    with open (filename) as f:
        data = csv.reader(f)
        count = 1
        for x in data:
            print (x)
            count += 1
            if count >10:
                break

                
print_data_from_csv("project.csv")
# Out:
# ['ï»¿date', 'country', 'total', 'male', 'female', 'AM', 'UAM']
# ['1', 'AFG', '19', '7', '1', '0', '11']
# ['1', 'AGO', '0', '0', '0', '0', '0']
# ['1', 'ALB', '0', '0', '0', '0', '0']
# ['1', 'BEN', '11', '10', '0', '0', '1']
# ['1', 'BFA', '3', '3', '0', '0', '0']
# ['1', 'BGD', '1', '1', '0', '0', '0']
# ['1', 'CIV', '131', '123', '0', '0', '8']
# ['1', 'CMR', '0', '0', '0', '0', '0']
# ['1', 'COG', '0', '0', '0', '0', '0']

# %%
#Getting the name of the countries in a dictionary
def load_names (file_name):
    with open (file_name) as f:
        data = csv.reader(f)
        
        mydata = {}
        for row in data:
            x = mydata.get(row[1],row[0])
            mydata[row[1]] = x
            
            
        return mydata

country_name = load_names("countries.codes.csv")
import pprint
pprint.pprint (country_name)
# Out:
# {'AFG': 'Afghanistan',
#  'AGO': 'Angola',
#  'ALB': 'Albania',
#  'ARG': 'Argentina',
#  'ARM': 'Armenia',
#  'AZE': 'Azerbaijan',
#  'BDI': 'Burundi',
#  'BEN': 'Benin',
#  'BFA': 'Burkina Faso',
#  'BGD': 'Bangladesh',
#  'BGR': 'Bulgaria',
#  'BIH': 'Bosnia and Herzegovina',
#  'BLZ': 'Belize',
#  'BOL': 'Bolivia',
#  'BRA': 'Brazil',
#  'CAF': 'Central African Republic',
#  'CHN': 'China',
#  'CIV': 'Ivory Coast',
#  'CMR': 'Cameroon',
#  'COD': 'Democratic Republic of the Congo',
#  'COG': 'Republic of the Congo',
#  'COL': 'Colombia',
#  'COM': 'Comoros',
#  'CPV': 'Cape Verde',
#  'CUB': 'Cuba',
#  'CYP': 'Cyprus',
#  'DJI': 'Djibouti',
#  'DOM': 'Dominican Republic',
#  'DZA': 'Algeria',
#  'ECU': 'Ecuador',
#  'EGY': 'Egypt',
#  'ERI': 'Eritrea',
#  'ESH': 'Western Sahara',
#  'ESP': 'Spain',
#  'ETH': 'Ethiopia',
#  'FRA': 'France',
#  'GAB': 'Gabon',
#  'GEO': 'Georgia',
#  'GHA': 'Ghana',
#  'GIN': 'Guinea',
#  'GMB': 'Gambia',
#  'GNB': 'Guinea-Bissau',
#  'GNQ': 'Equatorial Guinea',
#  'GRC': 'Greece',
#  'HND': 'Honduras',
#  'HRV': 'Croatia',
#  'HTI': 'Haiti',
#  'HUN': 'Hungary',
#  'IDN': 'Indonesia',
#  'IND': 'India',
#  'IRN': 'Iran',
#  'IRQ': 'Iraq',
#  'ISR': 'Israel',
#  'ITA': 'Italy',
#  'JAM': 'Jamaica',
#  'JOR': 'Jordan',
#  'KAZ': 'Kazakhstan',
#  'KEN': 'Kenya',
#  'KGZ': 'Kyrgyzstan',
#  'KWT': 'Kuwait',
#  'LBN': 'Lebanon',
#  'LBR': 'Liberia',
#  'LBY': 'Libya',
#  'LKA': 'Sri Lanka',
#  'LTU': 'Lithuania',
#  'MAR': 'Morocco',
#  'MDA': 'Moldova',
#  'MDG': 'Madagascar',
#  'MKD': 'fYROM',
#  'MLI': 'Mali',
#  'MLT': 'Malta',
#  'MMR': 'Myanmar',
#  'MRT': 'Mauritania',
#  'MUS': 'Mauritius',
#  'MWI': 'Malawi',
#  'MYS': 'Malaysia',
#  'NER': 'Niger',
#  'NGA': 'Nigeria',
#  'NPL': 'Nepal',
#  'OMN': 'Oman',
#  'OOO': 'Unidentified',
#  'PAK': 'Pakistan',
#  'PAN': 'Panama',
#  'PHL': 'Philippines',
#  'PRY': 'Paraguay',
#  'PSE': 'Palestinian Territory',
#  'RUS': 'Russia',
#  'RWA': 'Rwanda',
#  'SAU': 'Saudi Arabia',
#  'SDN': 'Sudan',
#  'SEN': 'Senegal',
#  'SLE': 'Sierra Leone',
#  'SOM': 'Somalia',
#  'SRB': 'Serbia',
#  'SSD': 'South Sudan',
#  'SVN': 'Slovenia',
#  'SWZ': 'Swaziland',
#  'SYR': 'Syria',
#  'TCD': 'Chad',
#  'TGO': 'Togo',
#  'TJK': 'Tajikistan',
#  'TKM': 'Turkmenistan',
#  'TON': 'Tongo',
#  'TUN': 'Tunisia',
#  'TUR': 'Turkey',
#  'TZA': 'Tanzania',
#  'UGA': 'Uganda',
#  'UKR': 'Ukraine',
#  'UZB': 'Uzbekistan',
#  'VEN': 'Venezuela',
#  'VNM': 'Vietnam',
#  'YEM': 'Yemen',
#  'ZAF': 'South Africa',
#  'ZMB': 'Zambia',
#  'ZWE': 'Zimbabwe'}

# %%
#Total per group per country 
def load_data(file_name):
    with open (file_name) as f:
        data = csv.reader(f)
        next(data)
        my_list = []
        for x in data:
            my_list.append(x)
    return my_list    

    
def total_per_group (my_list):
        my_dic = {}
        for line in my_list:
            country = line[1]
            X = my_dic.get(country, [0,0,0,0,0])
            for i in range (5):
                X[i] += int(line[i+2])
            my_dic[country] = X
        return my_dic
    
my_data = load_data('project.csv')
import pprint
great_dictionary = total_per_group(my_data)
pprint.pprint (great_dictionary)
# Out:
# {'AFG': [945, 516, 80, 28, 321],
#  'AGO': [9, 6, 0, 0, 3],
#  'ALB': [68, 68, 0, 0, 0],
#  'BEN': [2441, 2082, 13, 6, 340],
#  'BFA': [2611, 2443, 42, 5, 121],
#  'BGD': [31948, 29883, 45, 184, 1836],
#  'CIV': [22169, 18833, 1569, 158, 1609],
#  'CMR': [2550, 1582, 804, 63, 101],
#  'COG': [727, 371, 168, 83, 105],
#  'COM': [1102, 840, 254, 0, 8],
#  'DZA': [1084, 1059, 16, 4, 5],
#  'EGY': [12417, 4403, 100, 117, 7797],
#  'ERI': [243546, 161767, 54143, 7679, 19957],
#  'ETH': [17129, 12659, 3819, 205, 446],
#  'GAB': [22, 16, 0, 0, 6],
#  'GEO': [9, 9, 0, 0, 0],
#  'GHA': [24511, 22078, 844, 228, 1361],
#  'GIN': [13257, 11680, 103, 81, 1393],
#  'GMB': [50346, 43614, 409, 265, 6058],
#  'GNB': [2610, 2406, 22, 28, 154],
#  'GNQ': [384, 327, 15, 0, 42],
#  'GRC': [16, 16, 0, 0, 0],
#  'IND': [160, 160, 0, 0, 0],
#  'IRN': [755, 544, 88, 56, 67],
#  'IRQ': [5779, 3914, 769, 639, 457],
#  'JOR': [126, 17, 5, 59, 45],
#  'KEN': [108, 40, 68, 0, 0],
#  'KWT': [5, 5, 0, 0, 0],
#  'LBN': [95, 53, 15, 27, 0],
#  'LBR': [738, 649, 36, 0, 53],
#  'LBY': [3184, 2667, 212, 99, 206],
#  'MAR': [22188, 20614, 1164, 57, 353],
#  'MDG': [120, 61, 55, 4, 0],
#  'MLI': [37030, 33906, 320, 244, 2560],
#  'MMR': [5, 5, 0, 0, 0],
#  'MRT': [642, 634, 8, 0, 0],
#  'MUS': [12, 12, 0, 0, 0],
#  'NER': [884, 766, 29, 19, 70],
#  'NGA': [124413, 88452, 29200, 1309, 5452],
#  'NPL': [249, 242, 7, 0, 0],
#  'OOO': [58852, 54900, 2993, 134, 825],
#  'PAK': [13325, 12876, 211, 19, 219],
#  'PHL': [39, 12, 27, 0, 0],
#  'PSE': [12118, 6834, 2127, 1441, 1716],
#  'RWA': [10, 10, 0, 0, 0],
#  'SDN': [54702, 50867, 1949, 653, 1233],
#  'SEN': [38324, 35781, 210, 148, 2185],
#  'SLE': [1110, 827, 147, 27, 109],
#  'SOM': [78692, 51981, 16236, 2374, 8101],
#  'SYR': [53631, 31384, 8335, 9954, 3958],
#  'TCD': [1014, 936, 18, 21, 39],
#  'TGO': [2084, 1919, 32, 0, 133],
#  'TUN': [5738, 5489, 52, 13, 184],
#  'TUR': [14, 9, 0, 0, 5],
#  'UGA': [18, 12, 6, 0, 0],
#  'UKR': [149, 147, 2, 0, 0],
#  'VNM': [7, 0, 0, 0, 7],
#  'YEM': [248, 186, 43, 0, 19],
#  'ZAF': [9, 9, 0, 0, 0],
#  'ZMB': [10, 10, 0, 0, 0],
#  'ZWE': [11, 11, 0, 0, 0]}

# %%
from operator import itemgetter

greatest_list = sorted(great_dictionary.items(), key=itemgetter(1), reverse=True)

ten_items = greatest_list[:10]
for t in ten_items:
    print('Entry:', t[0])
    print('Entry:', t[1])
# Out:
# Entry: ERI
# Entry: [243546, 161767, 54143, 7679, 19957]
# Entry: NGA
# Entry: [124413, 88452, 29200, 1309, 5452]
# Entry: SOM
# Entry: [78692, 51981, 16236, 2374, 8101]
# Entry: OOO
# Entry: [58852, 54900, 2993, 134, 825]
# Entry: SDN
# Entry: [54702, 50867, 1949, 653, 1233]
# Entry: SYR
# Entry: [53631, 31384, 8335, 9954, 3958]
# Entry: GMB
# Entry: [50346, 43614, 409, 265, 6058]
# Entry: SEN
# Entry: [38324, 35781, 210, 148, 2185]
# Entry: MLI
# Entry: [37030, 33906, 320, 244, 2560]
# Entry: BGD
# Entry: [31948, 29883, 45, 184, 1836]

# %%
#getting the total per group 
def load_data(file_name):
    with open (file_name) as f:
        data = csv.reader(f)
        next(data)
        my_list = []
        for x in data:
            my_list.append(x)
    return my_list    

    
def total_per_group (index, my_list):
        second_list = []
        for line in my_list:
            second_list.append(int(line[index]))
            final_list = sum(second_list)
        return final_list
    
my_data = load_data('project.csv')
great_list = total_per_group(3,my_data)
print ('Male:',great_list)
great_list = total_per_group(4,my_data)
print ('Female:',great_list)
great_list = total_per_group(5,my_data)
print ('AM:',great_list)
great_list = total_per_group(6,my_data)
print ('UAM:',great_list)
# Out:
# Male: 723599
# Female: 126810
# AM: 26431
# UAM: 69659

# %%
import folium

from  geopy.geocoders import Nominatim

europe = [48.5260, 21.2551]
center = [26.851854, 16.302643]

fmap = folium.Map(location=center, zoom_start=4)


def plot_genders(fmap, data, range):
    gloc = Nominatim()
    divider = 2000
    for x in data[:range]:
        code = x[0]
        if code == 'OOO':
            continue
        name = country_name[code]
        total_females = x[1][2]/divider
        total_males = x[1][1]/divider
        total_AM = x[1][3]/divider
        total_UAM = x[1][4]/divider
        #print('Country code', code, 'and name', name,
        #      'total males', total_males, 'and females', total_females)
        country_location = gloc.geocode(name)
        #print(country_location.latitude, country_location.longitude)
        folium.CircleMarker(location=[country_location.latitude, country_location.longitude],
                            popup=str(total_females*divider),
                            radius=total_females, color='#FFD900', fill=False).add_to(fmap)
        folium.CircleMarker(location=[country_location.latitude, country_location.longitude],
                            popup=str(total_males*divider),
                            radius=total_males, color='#2574B0', fill=False).add_to(fmap)
        folium.CircleMarker(location=[country_location.latitude, country_location.longitude],
                            popup=str(total_AM*divider),
                            radius=total_AM, color='#5d1aa8', fill=False).add_to(fmap)
        folium.CircleMarker(location=[country_location.latitude, country_location.longitude],
                            popup=str(total_UAM*divider),
                            radius=total_UAM, color='#54e3ae', fill=False).add_to(fmap)
        
plot_genders(fmap, greatest_list, 20)



def create_legend():
    ''' Create a HTML legend for folium '''
    legend_html = '''
         <div style="position: fixed; 
         bottom: 10px; left: 10px; width: 140px; height: 110px; 
         border:1px solid grey; z-index:9999; font-size:10px;
         ">&nbsp; <b>Cool Legend</b> <br>
         &nbsp; Female &nbsp; <i class="fa fa-map-marker fa-2x"
                      style="color:blue"></i><br>
         &nbsp; Male &nbsp; <i class="fa fa-map-marker fa-2x"
                      style="color:yellow"></i><br>
         &nbsp; Accompanied Minors &nbsp; <i class="fa fa-map-marker fa-2x"
                      style="color:red"></i>
         <br>&nbsp; Unaccompanied Minors &nbsp; <i class="fa fa-map-marker fa-2x"
                      style="color:cyan"></i>
          </div>
         '''
    return legend_html

fmap.get_root().html.add_child(folium.Element(create_legend()))
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
